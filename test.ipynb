# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Project/hyundi.csv')
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
combined_data = pd.concat([df, df2,df3,df4], axis=0)

# %%
combined_data.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax(£)   mpg  \
# 0      I20  2017   7999       Manual    17307   Petrol   145.0  58.9
# 1   Tucson  2016  14499    Automatic    25233   Diesel   235.0  43.5
# 2   Tucson  2016  11399       Manual    37877   Diesel    30.0  61.7
# 3      I10  2016   6499       Manual    23789   Petrol    20.0  60.1
# 4     IX35  2015  10199       Manual    33177   Diesel   160.0  51.4
#
#    engineSize  tax
# 0         1.2  NaN
# 1         2.0  NaN
# 2         1.7  NaN
# 3         1.0  NaN
# 4         2.0  NaN

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40344 entries, 0 to 10780
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         40344 non-null  object
#  1   year          40344 non-null  int64
#  2   price         40344 non-null  int64
#  3   transmission  40344 non-null  object
#  4   mileage       40344 non-null  int64
#  5   fuelType      40344 non-null  object
#  6   tax(£)        4860 non-null   float64
#  7   mpg           40344 non-null  float64
#  8   engineSize    40344 non-null  float64
#  9   tax           35484 non-null  float64
# dtypes: float64(4), int64(3), object(3)
# memory usage: 3.4+ MB

# %%
combined_data.isnull().sum()
# Out:
# model               0
# year                0
# price               0
# transmission        0
# mileage             0
# fuelType            0
# tax(£)          35484
# mpg                 0
# engineSize          0
# tax              4860
# dtype: int64

# %%
combined_data=combined_data.drop(['tax(£)','tax','mpg'],axis=1)

# %%
combined_data.duplicated().sum()
# Out:
# 438

# %%
combined_data.drop_duplicates(inplace=True)

# %%
combined_data.duplicated().sum()
# Out:
# 0

# %%
#df=df.drop(['Max Power','Max Torque','Drivetrain','Length','Width','Height','Seating Capacity','Fuel Tank Capacity','Engine'],axis=1)

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40344 entries, 0 to 10780
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         40344 non-null  object
#  1   year          40344 non-null  int64
#  2   price         40344 non-null  int64
#  3   transmission  40344 non-null  object
#  4   mileage       40344 non-null  int64
#  5   fuelType      40344 non-null  object
#  6   engineSize    40344 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 2.5+ MB

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
name_le = LabelEncoder()
df["name"] = name_le.fit_transform(df["name"])
df.name.value_counts()
# Out:
# 971     54
# 793     48
# 814     42
# 811     30
# 993     28
#         ..
# 1394     1
# 1112     1
# 712      1
# 1350     1
# 601      1
# Name: name, Length: 1491, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
fuel_le = LabelEncoder()
df["fuel"] = fuel_le.fit_transform(df["fuel"])
df.fuel.value_counts()
# Out:
# 1    1800
# 4    1717
# 0      37
# 3      22
# 2       1
# Name: fuel, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
seller_type_le = LabelEncoder()
df["seller_type"] = seller_type_le.fit_transform(df["seller_type"])
df.seller_type.value_counts()
# Out:
# 1    2832
# 0     712
# 2      33
# Name: seller_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
transmission_le = LabelEncoder()
df["transmission"] = transmission_le.fit_transform(df["transmission"])
df.transmission.value_counts()
# Out:
# 1    3265
# 0     312
# Name: transmission, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
owner_le = LabelEncoder()
df["owner"] = owner_le.fit_transform(df["owner"])
df.owner.value_counts()
# Out:
# 0    2218
# 2     978
# 4     289
# 1      75
# 3      17
# Name: owner, dtype: int64

# %% [markdown]
# **For loop Encoder**

# %%
from sklearn.preprocessing import OrdinalEncoder
list_encoder = ['model' ,'transmission' ,'fuelType','engineSize']
label_encoder = LabelEncoder()
for column in list_encoder:
    combined_data[column] = label_encoder.fit_transform(combined_data[column])

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40344 entries, 0 to 10780
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         40344 non-null  int64
#  1   year          40344 non-null  int64
#  2   price         40344 non-null  int64
#  3   transmission  40344 non-null  int64
#  4   mileage       40344 non-null  int64
#  5   fuelType      40344 non-null  int64
#  6   engineSize    40344 non-null  int64
# dtypes: int64(7)
# memory usage: 2.5 MB

# %%
combined_data.head()
# Out:
#    model  year  price  transmission  mileage  fuelType  engineSize
# 0     31  2017   7999             1    17307         4           4
# 1     64  2016  14499             0    25233         0          12
# 2     64  2016  11399             1    37877         0           9
# 3     30  2016   6499             1    23789         4           2
# 4     37  2015  10199             1    33177         0          12

# %%
combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40344 entries, 0 to 10780
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         40344 non-null  int64
#  1   year          40344 non-null  int64
#  2   price         40344 non-null  int64
#  3   transmission  40344 non-null  int64
#  4   mileage       40344 non-null  int64
#  5   fuelType      40344 non-null  int64
#  6   engineSize    40344 non-null  int64
# dtypes: int64(7)
# memory usage: 2.5 MB

# %%
combined_data.head()
# Out:
#    model  year  price  transmission  mileage  fuelType  engineSize
# 0     31  2017   7999             1    17307         4           4
# 1     64  2016  14499             0    25233         0          12
# 2     64  2016  11399             1    37877         0           9
# 3     30  2016   6499             1    23789         4           2
# 4     37  2015  10199             1    33177         0          12

# %%
combined_data.duplicated().sum()
# Out:
# 438

# %%
#X = df.to_numpy()
#y = df.drop(['Price'],axis=1)
X = combined_data.drop(['price'] , axis = 1)
y = combined_data['price']
#scaler = StandardScaler()
#X_scaled = scaler.fit_transform(X)

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42,shuffle=True)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
print(f"Mean Absolute Error: {mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"R2 Score: {r2_score(y_test,y_pred)}")
# Out:
# Mean Absolute Error: 3164.620435960183
# Mean Squared Error: 21690162.66537029
# Root Mean Squared Error: 4657.269872507958
# R2 Score: 0.7113749113863128

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(X_test)
print(f"Mean Absolute Error: {mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"R2 Score: {r2_score(y_test,y_pred)}")
# Out:
# Mean Absolute Error: 1080.2294836196781
# Mean Squared Error: 3115184.5943224034
# Root Mean Squared Error: 1764.9885535952926
# R2 Score: 0.9585470868312206

# %%
from sklearn.svm import SVR

# %%
model = SVR()
model.fit(X_train,y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(X_test)
print(f"Mean Absolute Error: {mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"R2 Score: {r2_score(y_test,y_pred)}")
# Out:
# Mean Absolute Error: 4872.915540902446
# Mean Squared Error: 64458793.166257754
# Root Mean Squared Error: 8028.6233668206005
# R2 Score: 0.15929021293695245

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)
print(f"Mean Absolute Error: {mean_absolute_error(y_test,y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,y_pred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,y_pred))}")
print(f"R2 Score: {r2_score(y_test,y_pred)}")
# Out:
# Mean Absolute Error: 1083.2034775529194
# Mean Squared Error: 5027531.64882337
# Root Mean Squared Error: 2242.215789977265
# R2 Score: 0.8757303641407528
